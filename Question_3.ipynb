# %%
# Question 3. Statistics

# %%
# Make use of the make_blobs from the library sklearns.datasets to create three groups/classes:

# %%
from sklearn.datasets import make_blobs
from matplotlib import pyplot
from pandas import DataFrame
X, y = make_blobs(2000, 2, centers=3, random_state=2, cluster_std=1.5)
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
display(df)
colors = {0:'red', 1:'blue', 2:'green'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax,kind='scatter', x='x', y='y', label="group " + str(key), color=colors[key])
pyplot.show()
# Out:
#              x          y  label
# 0    -0.737842  -6.208879      0
# 1     0.213671  -2.518169      2
# 2     2.417704  -2.323025      1
# 3    -1.797037 -12.484594      0
# 4     0.210156 -11.997823      0
# ...        ...        ...    ...
# 1995 -0.566354  -3.468944      2
# 1996 -3.334560  -5.475969      0
# 1997 -2.288798 -11.825417      0
# 1998 -0.023678  -9.678999      0
# 1999  1.200821   0.013531      1
#
# [2000 rows x 3 columns]

# %%
#Apply GaussianNB to learn on these data and plot about 2000 random points in the plane with corresponding 
#colors to its class prediction. Print out the mean and standard deviation of each groups after learning

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X, y);

# %%
rng = np.random.RandomState(0)
Xnew = [-6, -14] + [14, 18] * rng.rand(2000, 2)
ynew = model.predict(Xnew)

# %%
df = DataFrame(dict(x=Xnew[:,0], y=Xnew[:,1], label=ynew))
display(df)
colors = {0:'red', 1:'blue', 2:'green'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax,kind='scatter', x='x', y='y', label="group " + str(key), color=colors[key])
pyplot.show()
# Out:
#              x         y  label
# 0     1.683389 -1.126591      1
# 1     2.438687 -4.192103      1
# 2    -0.068833 -2.373906      1
# 3     0.126221  2.051914      1
# 4     7.491279 -7.098053      1
# ...        ...       ...    ...
# 1995 -0.603425 -9.648491      0
# 1996 -3.371216 -6.715763      0
# 1997 -4.321345 -7.706491      0
# 1998  0.088231  0.940053      1
# 1999  7.059287 -8.449908      0
#
# [2000 rows x 3 columns]

# %%
print("Mean of each class \n" , model.theta_)
print("Standard Deviation of each class \n" , model.sigma_)
# Out:
# Mean of each class
#  [[-1.27117188 -9.58291458]
#  [ 1.08849576 -1.40624828]
#  [-1.5350356  -3.52884247]]
# Standard Deviation of each class
#  [[2.15547458 2.21883898]
#  [2.29111572 2.15172823]
#  [2.47396079 2.42751701]]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `sigma_` was deprecated in 1.0 and will be removed in1.2. Use `var_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
yprob = model.predict_proba(Xnew)
yprob[-8:].round(2)
# Out:
# array([[0.  , 0.  , 1.  ],
#        [1.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  ],
#        [1.  , 0.  , 0.  ],
#        [0.5 , 0.  , 0.5 ],
#        [0.91, 0.  , 0.09],
#        [0.  , 0.96, 0.04],
#        [0.93, 0.05, 0.02]])

# %%
# Question 2. Calculus
# Assume the loss function of an AI algorithm is y = x 3 - 2*x 2 + 1.
# A. Plot the function in plane and its derivative
# B. Using the Gradient Descent to find the x to make this function get the minimum loss.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-whitegrid')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-10,10);
y=x**3 - 2*(x**2)+1
dy_dx = np.gradient(y, x)
plt.axhline(0, color='black', alpha = 0.3)
plt.axvline(0, color='black', alpha = 0.3)
plt.plot(x,y, color = "red", label = "y= x^3 - 2x^2 + 1")
plt.plot(x,dy_dx , color='blue', label='Derivative')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.axis("tight")
plt.legend()
plt.show()

# %%
# !pip install numdifftools

# %%
x = np.linspace(-1,2,500)
y = x**3 - 2*(x**2)+1
plt.plot(x,y, color = "red")
plt.axhline(0, color='black', alpha = 0.7)
plt.axvline(0, color='black', alpha = 0.7)
plt.grid()
plt.axis("tight")
plt.title("Function x^3 - 2x^2+1")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
import numdifftools as nd 
dydx = lambda x : float(nd.Gradient(function)([x])) 
x_sample = 2
print(f"Derivatives of function at {x_sample} is {dydx(x_sample)}")
# Out:
# Derivatives of function at 2 is 4.00000000000001

# %%
def step(x_new, x_prev, precision, l_r):
    # create empty lists where the updated values of x and y wil be appended during each iteration
    x_list, y_list = [x_new], [function(x_new)]
    # keep looping until your desired precision
    while abs(x_new - x_prev) > precision:
        # change the value of x
        x_prev = x_new
        # get the derivation of the old value of x
        d_x = - dydx(x_prev)
        # get your new value of x by adding the previous, the multiplication of the derivative and the learning rate
        x_new = x_prev + (l_r * d_x)
        # append the new value of x to a list of all x-s for later visualization of path
        x_list.append(x_new)
        # append the new value of y to a list of all y-s for later visualization of path
        y_list.append(function(x_new))
    x_min = x_new
    print ("Local minimum occurs at: "+ str(round(x_min,6)))
    print ("Number of steps: " + str(len(x_list)))
    
    return x_list, y_list, x_min

# %%
#Implement gradient descent (all the arguments are arbitrarily chosen)
x_list, y_list, x_min = step(x_new = 0.5, x_prev = 0, precision = 0.001, l_r = 0.05)
plt.plot(x,y, color = "blue")
plt.scatter(x_list,y_list,c="r")
plt.axhline(0, color='y', alpha = 0.7)
plt.axvline(0, color='y', alpha = 0.7)
plt.grid()
plt.title("Function x^3-2x^2+1")
plt.show()
# Out:
# Local minimum occurs at: 1.329867
# Number of steps: 31

# %%
plt.scatter(x_list,y_list,c="b")
plt.plot(x_list,y_list,c="b")
plt.plot(x,y, c="r")
plt.xlim([1.0,2.1])
plt.ylim([-1.0,1.0])
plt.title("Zoomed in Gradient descent to Key Area")
plt.grid()
plt.show()
